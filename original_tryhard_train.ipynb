# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ipynb.fs.full.Models import *

import time as timer

model = SIR

# %%
#time dependencies
times=['lock','exp','fermi','rational']
time=times[0]

# %%
#weights weights configurations read from best_params file
fname = 'init_params.csv'
df = pd.read_csv(fname, sep=';')
df.index = df.Model
a_ws = np.array(df.loc[time].a)
r_ws = np.array(df.loc[time].r)
weights = [(float(a_ws[i]),float(r_ws[i])) for i in range(len(a_ws))]

#train
t1 = timer.time()
for time in times:
    models = []
    
    #load models
    for i,country in enumerate(countries):
        models.append(Model(country,model,time=time,start=starts[i]))
        print('')
    
    a_w = 0.
    r_w = 0.
    
    init_params = getInitParams(model=time, a=a_w, r=r_w)
        
    for i, mod in enumerate(models):
        n_fit=0
        mod.fit(init_params.iloc[i], a=a_w, r=r_w, fitOriginalData=True)
            
        if not mod.success: print('begin TRYHARD')
        else: print('Easy SUCCESS')
                
        while (not mod.success) & (n_fit <=10):
            mod.fit(mod.optimal, a=a_w, r=r_w, fitOriginalData=True, printer=False)
            n_fit+=1
        if n_fit !=0: print('# add. Fits until SUCCESS:', n_fit)
        
    best_params = printOptimized(models, params = init_params.columns.tolist())
    fname='original_params/'+time+'.csv'
    best_params.to_csv(fname)
t2=timer.time()
# Out:
# Creating SIR for Italy
# Loaded country's population
# Loaded time series of 116 days
# Lockdown at 2020-03-11 -> at day 49
# VA-lockdown index: 32
#
# Creating SIR for Germany
# Loaded country's population
# Loaded time series of 111 days
# Lockdown at 2020-03-20 -> at day 58
# VA-lockdown index: 41
#
# Creating SIR for Spain
# Loaded country's population
# Loaded time series of 113 days
# Lockdown at 2020-03-14 -> at day 52
# VA-lockdown index: 35
#
# Creating SIR for United Kingdom
# Loaded country's population
# Loaded time series of 109 days
# Lockdown at 2020-03-23 -> at day 61
# VA-lockdown index: 44
#
# Creating SIR for Belgium
# Loaded country's population
# Loaded time series of 107 days
# Lockdown at 2020-03-17 -> at day 55
# VA-lockdown index: 38
#
# Creating SIR for Portugal
# Loaded country's population
# Loaded time series of 106 days
# Lockdown at 2020-03-18 -> at day 56
# VA-lockdown index: 39
#
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[5.41415722e-01, 2.85227187e-01, 7.65548452e-04, 5.91606929e+00,
#         2.79473084e-01],
#        [5.41358236e-01, 2.85160560e-01, 7.65719517e-04, 5.91606765e+00,
#         2.79455224e-01],
#        [5.41473334e-01, 2.85295339e-01, 7.65372273e-04, 5.91606087e+00,
#         2.79488339e-01],
#        [5.41403013e-01, 2.85224279e-01, 7.65550354e-04, 5.91605479e+00,
#         2.79456054e-01],
#        [5.41408049e-01, 2.85219216e-01, 7.65566201e-04, 5.91603274e+00,
#         2.79464777e-01],
#        [5.41324157e-01, 2.85134501e-01, 7.65779930e-04, 5.91604784e+00,
#         2.79429294e-01]]), array([8.69768711e-08, 8.69774723e-08, 8.69775391e-08, 8.69782815e-08,
#        8.69783576e-08, 8.69784645e-08]))
#            fun: 8.697687111523086e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 987
#            nit: 517
#         status: 0
#        success: True
#              x: array([5.41415722e-01, 2.85227187e-01, 7.65548452e-04, 5.91606929e+00,
#        2.79473084e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[6.34237633e-01, 4.10866377e-01, 3.75457212e-04, 5.74456369e+00,
#         3.98103299e-01],
#        [6.34250414e-01, 4.10879328e-01, 3.75443803e-04, 5.74459694e+00,
#         3.98082629e-01],
#        [6.34256566e-01, 4.10875386e-01, 3.75440272e-04, 5.74461772e+00,
#         3.98087668e-01],
#        [6.34233286e-01, 4.10861722e-01, 3.75466882e-04, 5.74464715e+00,
#         3.98089231e-01],
#        [6.34220947e-01, 4.10852649e-01, 3.75480868e-04, 5.74465214e+00,
#         3.98095390e-01],
#        [6.34175753e-01, 4.10831505e-01, 3.75525731e-04, 5.74463270e+00,
#         3.98110069e-01]]), array([3.14916277e-08, 3.14919047e-08, 3.14920723e-08, 3.14921630e-08,
#        3.14922427e-08, 3.14922647e-08]))
#            fun: 3.1491627662206955e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 589
#            nit: 317
#         status: 0
#        success: True
#              x: array([6.34237633e-01, 4.10866377e-01, 3.75457212e-04, 5.74456369e+00,
#        3.98103299e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[6.58726020e-01, 4.21631186e-01, 4.67831378e-04, 5.56777949e+00,
#         4.14198100e-01],
#        [6.58712979e-01, 4.21613758e-01, 4.67854567e-04, 5.56777984e+00,
#         4.14196183e-01],
#        [6.58727171e-01, 4.21611972e-01, 4.67804610e-04, 5.56787346e+00,
#         4.14147751e-01],
#        [6.58644093e-01, 4.21560949e-01, 4.67958586e-04, 5.56779315e+00,
#         4.14213981e-01],
#        [6.58705917e-01, 4.21587935e-01, 4.67840509e-04, 5.56787891e+00,
#         4.14148220e-01],
#        [6.58791377e-01, 4.21625964e-01, 4.67731911e-04, 5.56780421e+00,
#         4.14112221e-01]]), array([2.46355301e-07, 2.46358581e-07, 2.46371257e-07, 2.46371754e-07,
#        2.46372045e-07, 2.46375605e-07]))
#            fun: 2.463553008570945e-07
#        message: 'Optimization terminated successfully.'
#           nfev: 664
#            nit: 355
#         status: 0
#        success: True
#              x: array([6.58726020e-01, 4.21631186e-01, 4.67831378e-04, 5.56777949e+00,
#        4.14198100e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[5.76171692e-01, 3.40011690e-01, 5.28227665e-04, 5.67849883e+00,
#         3.62817789e-01],
#        [5.76096489e-01, 3.39967982e-01, 5.28326765e-04, 5.67851138e+00,
#         3.62831319e-01],
#        [5.76076803e-01, 3.39944064e-01, 5.28362799e-04, 5.67851420e+00,
#         3.62839471e-01],
#        [5.76099267e-01, 3.39953555e-01, 5.28334748e-04, 5.67851851e+00,
#         3.62837749e-01],
#        [5.76221599e-01, 3.40024202e-01, 5.28174239e-04, 5.67851626e+00,
#         3.62815208e-01],
#        [5.76253658e-01, 3.40043464e-01, 5.28132618e-04, 5.67851114e+00,
#         3.62808194e-01]]), array([7.61481246e-08, 7.61484016e-08, 7.61484611e-08, 7.61487694e-08,
#        7.61491888e-08, 7.61498230e-08]))
#            fun: 7.614812459834909e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 639
#            nit: 330
#         status: 0
#        success: True
#              x: array([5.76171692e-01, 3.40011690e-01, 5.28227665e-04, 5.67849883e+00,
#        3.62817789e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[5.90217972e-01, 3.70267466e-01, 4.02325675e-04, 6.40312778e+00,
#         3.55627913e-01],
#        [5.90243073e-01, 3.70276737e-01, 4.02345542e-04, 6.40312626e+00,
#         3.55568789e-01],
#        [5.90209085e-01, 3.70261024e-01, 4.02329549e-04, 6.40314491e+00,
#         3.55638564e-01],
#        [5.90198497e-01, 3.70258786e-01, 4.02298672e-04, 6.40316994e+00,
#         3.55681262e-01],
#        [5.90209558e-01, 3.70258229e-01, 4.02369952e-04, 6.40314610e+00,
#         3.55593121e-01],
#        [5.90210404e-01, 3.70259432e-01, 4.02336048e-04, 6.40317571e+00,
#         3.55624996e-01]]), array([6.70194593e-08, 6.70209337e-08, 6.70210183e-08, 6.70211411e-08,
#        6.70213379e-08, 6.70214212e-08]))
#            fun: 6.701945934095878e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 678
#            nit: 378
#         status: 0
#        success: True
#              x: array([5.90217972e-01, 3.70267466e-01, 4.02325675e-04, 6.40312778e+00,
#        3.55627913e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[6.42025294e-01, 3.92487376e-01, 3.87023031e-04, 5.47724786e+00,
#         3.92544091e-01],
#        [6.42064697e-01, 3.92506034e-01, 3.87008061e-04, 5.47726272e+00,
#         3.92518054e-01],
#        [6.42018203e-01, 3.92484455e-01, 3.87026500e-04, 5.47727509e+00,
#         3.92547310e-01],
#        [6.42037594e-01, 3.92491631e-01, 3.87019448e-04, 5.47732662e+00,
#         3.92533451e-01],
#        [6.42021811e-01, 3.92488276e-01, 3.87021961e-04, 5.47728893e+00,
#         3.92543815e-01],
#        [6.42036119e-01, 3.92491814e-01, 3.87018720e-04, 5.47734491e+00,
#         3.92533392e-01]]), array([4.70822823e-08, 4.70823370e-08, 4.70824077e-08, 4.70824269e-08,
#        4.70824284e-08, 4.70824551e-08]))
#            fun: 4.708228232908603e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 490
#            nit: 264
#         status: 0
#        success: True
#              x: array([6.42025294e-01, 3.92487376e-01, 3.87023031e-04, 5.47724786e+00,
#        3.92544091e-01])
# Easy SUCCESS
# Creating SIR for Italy
# Loaded country's population
# Loaded time series of 116 days
# Lockdown at 2020-03-11 -> at day 49
# VA-lockdown index: 32
#
# Creating SIR for Germany
# Loaded country's population
# Loaded time series of 111 days
# Lockdown at 2020-03-20 -> at day 58
# VA-lockdown index: 41
#
# Creating SIR for Spain
# Loaded country's population
# Loaded time series of 113 days
# Lockdown at 2020-03-14 -> at day 52
# VA-lockdown index: 35
#
# Creating SIR for United Kingdom
# Loaded country's population
# Loaded time series of 109 days
# Lockdown at 2020-03-23 -> at day 61
# VA-lockdown index: 44
#
# Creating SIR for Belgium
# Loaded country's population
# Loaded time series of 107 days
# Lockdown at 2020-03-17 -> at day 55
# VA-lockdown index: 38
#
# Creating SIR for Portugal
# Loaded country's population
# Loaded time series of 106 days
# Lockdown at 2020-03-18 -> at day 56
# VA-lockdown index: 39
#
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[9.04120182e-01, 9.94140842e-02, 3.23700007e-05, 2.23888852e-01],
#        [9.04031674e-01, 9.94260742e-02, 3.23799116e-05, 2.23871347e-01],
#        [9.04120131e-01, 9.94114302e-02, 3.23728730e-05, 2.23892471e-01],
#        [9.04034652e-01, 9.94345829e-02, 3.23813101e-05, 2.23869969e-01],
#        [9.04058866e-01, 9.94139302e-02, 3.23805133e-05, 2.23877855e-01]]), array([1.63734160e-09, 1.63746599e-09, 1.63748521e-09, 1.63750674e-09,
#        1.63763703e-09]))
#            fun: 1.6373415970317064e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 135
#            nit: 73
#         status: 0
#        success: True
#              x: array([9.04120182e-01, 9.94140842e-02, 3.23700007e-05, 2.23888852e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[9.87300958e-01, 2.99156723e-01, 6.96761893e-06, 1.99647731e-01],
#        [9.87264734e-01, 2.99064985e-01, 6.96806536e-06, 1.99656543e-01],
#        [9.87363428e-01, 2.99225157e-01, 6.95689943e-06, 1.99633295e-01],
#        [9.87279507e-01, 2.99101856e-01, 6.96621475e-06, 1.99650243e-01],
#        [9.87243154e-01, 2.99067969e-01, 6.97197857e-06, 1.99657286e-01]]), array([1.44542096e-09, 1.44542960e-09, 1.44543749e-09, 1.44544676e-09,
#        1.44544816e-09]))
#            fun: 1.4454209649570232e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 833
#            nit: 499
#         status: 0
#        success: True
#              x: array([9.87300958e-01, 2.99156723e-01, 6.96761893e-06, 1.99647731e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[1.30706982e+00, 2.49365050e-01, 7.66133427e-08, 2.28118039e-01],
#        [1.30687176e+00, 2.48579296e-01, 7.69848349e-08, 2.28208868e-01],
#        [1.30610377e+00, 2.49534832e-01, 7.73933152e-08, 2.27998563e-01],
#        [1.30627080e+00, 2.49871525e-01, 7.70356078e-08, 2.27956275e-01],
#        [1.30639437e+00, 2.49266604e-01, 7.75848663e-08, 2.28105611e-01]]), array([5.75297536e-09, 5.75556877e-09, 5.75727694e-09, 5.75732863e-09,
#        5.75776800e-09]))
#            fun: 5.752975356835479e-09
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 4000
#            nit: 2447
#         status: 1
#        success: False
#              x: array([1.30706982e+00, 2.49365050e-01, 7.66133427e-08, 2.28118039e-01])
# begin TRYHARD
# # add. Fits until SUCCESS: 1
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[1.04450707e+00, 2.42969807e-03, 1.03723001e-06, 2.17816282e-01],
#        [1.04437587e+00, 2.45842500e-03, 1.03980943e-06, 2.17814017e-01],
#        [1.04430299e+00, 2.91160737e-03, 1.04052573e-06, 2.17804563e-01],
#        [1.04418650e+00, 2.43286875e-03, 1.04216883e-06, 2.17796960e-01],
#        [1.04406559e+00, 2.50070808e-03, 1.04419698e-06, 2.17790733e-01]]), array([7.33234918e-10, 7.33260730e-10, 7.33278755e-10, 7.33281641e-10,
#        7.33285254e-10]))
#            fun: 7.332349177460126e-10
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 4000
#            nit: 2482
#         status: 1
#        success: False
#              x: array([1.04450707e+00, 2.42969807e-03, 1.03723001e-06, 2.17816282e-01])
# begin TRYHARD
# # add. Fits until SUCCESS: 1
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[9.04636332e-01, 2.71335101e-01, 2.16974409e-05, 1.92043037e-01],
#        [9.04650711e-01, 2.71300456e-01, 2.16985732e-05, 1.92054348e-01],
#        [9.04625548e-01, 2.71253746e-01, 2.17027689e-05, 1.92058751e-01],
#        [9.04631265e-01, 2.71372384e-01, 2.16960622e-05, 1.92034116e-01],
#        [9.04650283e-01, 2.71402530e-01, 2.16936610e-05, 1.92032007e-01]]), array([2.24015426e-09, 2.24016129e-09, 2.24016497e-09, 2.24017160e-09,
#        2.24017338e-09]))
#            fun: 2.2401542560746127e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 679
#            nit: 404
#         status: 0
#        success: True
#              x: array([9.04636332e-01, 2.71335101e-01, 2.16974409e-05, 1.92043037e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[1.24069989e+00, 3.85688778e-02, 4.59002373e-07, 2.50063118e-01],
#        [1.24076185e+00, 3.85483187e-02, 4.58624893e-07, 2.50067217e-01],
#        [1.24062944e+00, 3.85921847e-02, 4.59420030e-07, 2.50058375e-01],
#        [1.24071104e+00, 3.85618339e-02, 4.58805960e-07, 2.50061010e-01],
#        [1.24060935e+00, 3.85991021e-02, 4.59548646e-07, 2.50057264e-01]]), array([2.68230664e-09, 2.68230775e-09, 2.68230822e-09, 2.68230841e-09,
#        2.68230893e-09]))
#            fun: 2.6823066416616486e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 3457
#            nit: 2119
#         status: 0
#        success: True
#              x: array([1.24069989e+00, 3.85688778e-02, 4.59002373e-07, 2.50063118e-01])
# Easy SUCCESS
# Creating SIR for Italy
# Loaded country's population
# Loaded time series of 116 days
# Lockdown at 2020-03-11 -> at day 49
# VA-lockdown index: 32
#
# Creating SIR for Germany
# Loaded country's population
# Loaded time series of 111 days
# Lockdown at 2020-03-20 -> at day 58
# VA-lockdown index: 41
#
# Creating SIR for Spain
# Loaded country's population
# Loaded time series of 113 days
# Lockdown at 2020-03-14 -> at day 52
# VA-lockdown index: 35
#
# Creating SIR for United Kingdom
# Loaded country's population
# Loaded time series of 109 days
# Lockdown at 2020-03-23 -> at day 61
# VA-lockdown index: 44
#
# Creating SIR for Belgium
# Loaded country's population
# Loaded time series of 107 days
# Lockdown at 2020-03-17 -> at day 55
# VA-lockdown index: 38
#
# Creating SIR for Portugal
# Loaded country's population
# Loaded time series of 106 days
# Lockdown at 2020-03-18 -> at day 56
# VA-lockdown index: 39
#
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[7.26617668e-01, 1.25492830e-02, 4.50511730e-05, 2.46360812e-01,
#         2.23270542e+00],
#        [7.26612643e-01, 1.25485476e-02, 4.50510381e-05, 2.46361195e-01,
#         2.23279635e+00],
#        [7.26619885e-01, 1.25467998e-02, 4.50516775e-05, 2.46360581e-01,
#         2.23265429e+00],
#        [7.26624603e-01, 1.25582294e-02, 4.50500560e-05, 2.46360626e-01,
#         2.23261854e+00],
#        [7.26619507e-01, 1.25608960e-02, 4.50494210e-05, 2.46360896e-01,
#         2.23271686e+00],
#        [7.26618384e-01, 1.25492748e-02, 4.50512197e-05, 2.46360701e-01,
#         2.23269030e+00]]), array([1.0153971e-09, 1.0153971e-09, 1.0153971e-09, 1.0153971e-09,
#        1.0153971e-09, 1.0153971e-09]))
#            fun: 1.0153971006911656e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 2335
#            nit: 1418
#         status: 0
#        success: True
#              x: array([7.26617668e-01, 1.25492830e-02, 4.50511730e-05, 2.46360812e-01,
#        2.23270542e+00])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[7.78400277e-01, 5.36180555e-03, 8.06632686e-07, 2.84939899e-01,
#         3.95725783e+00],
#        [7.77720844e-01, 5.49547516e-03, 8.09155723e-07, 2.84967347e-01,
#         3.96181571e+00],
#        [7.78033864e-01, 5.59482193e-03, 8.12213927e-07, 2.84916970e-01,
#         3.95804609e+00],
#        [7.76695971e-01, 5.28442227e-03, 8.03810057e-07, 2.85161651e-01,
#         3.97289949e+00],
#        [7.76780740e-01, 5.54538748e-03, 8.10078802e-07, 2.85067125e-01,
#         3.96948274e+00],
#        [7.77545783e-01, 5.51386008e-03, 8.10025960e-07, 2.85002941e-01,
#         3.96312571e+00]]), array([6.49353718e-10, 6.49472674e-10, 6.49490861e-10, 6.49504073e-10,
#        6.49507008e-10, 6.49524636e-10]))
#            fun: 6.493537175037804e-10
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 5001
#            nit: 3148
#         status: 1
#        success: False
#              x: array([7.78400277e-01, 5.36180555e-03, 8.06632686e-07, 2.84939899e-01,
#        3.95725783e+00])
# begin TRYHARD
# # add. Fits until SUCCESS: 1
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[8.55988011e-01, 3.60422627e-02, 4.34342716e-08, 2.92946519e-01,
#         4.24826914e+00],
#        [8.55986271e-01, 3.60316819e-02, 4.34187339e-08, 2.92949483e-01,
#         4.24836451e+00],
#        [8.55988336e-01, 3.60411511e-02, 4.34328105e-08, 2.92946964e-01,
#         4.24827570e+00],
#        [8.55987314e-01, 3.60414941e-02, 4.34329636e-08, 2.92946585e-01,
#         4.24827995e+00],
#        [8.55988119e-01, 3.60423479e-02, 4.34343702e-08, 2.92946520e-01,
#         4.24826774e+00],
#        [8.55987414e-01, 3.60388331e-02, 4.34291658e-08, 2.92947471e-01,
#         4.24830028e+00]]), array([3.57990649e-09, 3.57990650e-09, 3.57990650e-09, 3.57990651e-09,
#        3.57990651e-09, 3.57990652e-09]))
#            fun: 3.5799064943651266e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 4211
#            nit: 2635
#         status: 0
#        success: True
#              x: array([8.55988011e-01, 3.60422627e-02, 4.34342716e-08, 2.92946519e-01,
#        4.24826914e+00])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[ 7.45928027e-01, -2.17130970e-03,  1.25438857e-05,
#          2.22725915e-01,  1.89368415e+00],
#        [ 7.45920389e-01, -2.16526234e-03,  1.25446382e-05,
#          2.22725824e-01,  1.89378054e+00],
#        [ 7.45932958e-01, -2.17010182e-03,  1.25433345e-05,
#          2.22725994e-01,  1.89362672e+00],
#        [ 7.45928355e-01, -2.16909307e-03,  1.25438142e-05,
#          2.22725918e-01,  1.89368214e+00],
#        [ 7.45934999e-01, -2.16483203e-03,  1.25430856e-05,
#          2.22726109e-01,  1.89360882e+00],
#        [ 7.45922200e-01, -2.17321978e-03,  1.25445441e-05,
#          2.22725847e-01,  1.89375233e+00]]), array([8.63076161e-10, 8.63076162e-10, 8.63076162e-10, 8.63076162e-10,
#        8.63076162e-10, 8.63076162e-10]))
#            fun: 8.630761611076042e-10
#        message: 'Optimization terminated successfully.'
#           nfev: 3350
#            nit: 2083
#         status: 0
#        success: True
#              x: array([ 7.45928027e-01, -2.17130970e-03,  1.25438857e-05,  2.22725915e-01,
#         1.89368415e+00])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[5.99115696e-01, 3.32755759e-02, 2.09521516e-05, 2.65818245e-01,
#         4.50855829e+00],
#        [5.99119895e-01, 3.32799146e-02, 2.09520878e-05, 2.65817249e-01,
#         4.50851141e+00],
#        [5.99110389e-01, 3.32710792e-02, 2.09521256e-05, 2.65819099e-01,
#         4.50861746e+00],
#        [5.99108302e-01, 3.32688389e-02, 2.09521707e-05, 2.65819624e-01,
#         4.50864063e+00],
#        [5.99119092e-01, 3.32786518e-02, 2.09521620e-05, 2.65817592e-01,
#         4.50851960e+00],
#        [5.99116741e-01, 3.32772306e-02, 2.09520833e-05, 2.65817753e-01,
#         4.50854631e+00]]), array([1.14636985e-09, 1.14636985e-09, 1.14636986e-09, 1.14636986e-09,
#        1.14636986e-09, 1.14636986e-09]))
#            fun: 1.1463698516248338e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 1414
#            nit: 850
#         status: 0
#        success: True
#              x: array([5.99115696e-01, 3.32755759e-02, 2.09521516e-05, 2.65818245e-01,
#        4.50855829e+00])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[ 9.15147377e-01, -2.97739406e-04,  7.97582256e-06,
#          2.53139336e-01,  4.46714636e-01],
#        [ 9.15155985e-01, -2.89946243e-04,  7.97496317e-06,
#          2.53139739e-01,  4.46635381e-01],
#        [ 9.15157316e-01, -2.88122847e-04,  7.97486454e-06,
#          2.53139883e-01,  4.46624820e-01],
#        [ 9.15143739e-01, -2.86637484e-04,  7.97615668e-06,
#          2.53139219e-01,  4.46768157e-01],
#        [ 9.15154100e-01, -2.93517313e-04,  7.97518743e-06,
#          2.53139705e-01,  4.46650723e-01],
#        [ 9.15153947e-01, -2.84938869e-04,  7.97515302e-06,
#          2.53139680e-01,  4.46663847e-01]]), array([2.8252452e-09, 2.8252452e-09, 2.8252452e-09, 2.8252452e-09,
#        2.8252452e-09, 2.8252452e-09]))
#            fun: 2.8252451988795785e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 2875
#            nit: 1769
#         status: 0
#        success: True
#              x: array([ 9.15147377e-01, -2.97739406e-04,  7.97582256e-06,  2.53139336e-01,
#         4.46714636e-01])
# Easy SUCCESS
# Creating SIR for Italy
# Loaded country's population
# Loaded time series of 116 days
# Lockdown at 2020-03-11 -> at day 49
# VA-lockdown index: 32
#
# Creating SIR for Germany
# Loaded country's population
# Loaded time series of 111 days
# Lockdown at 2020-03-20 -> at day 58
# VA-lockdown index: 41
#
# Creating SIR for Spain
# Loaded country's population
# Loaded time series of 113 days
# Lockdown at 2020-03-14 -> at day 52
# VA-lockdown index: 35
#
# Creating SIR for United Kingdom
# Loaded country's population
# Loaded time series of 109 days
# Lockdown at 2020-03-23 -> at day 61
# VA-lockdown index: 44
#
# Creating SIR for Belgium
# Loaded country's population
# Loaded time series of 107 days
# Lockdown at 2020-03-17 -> at day 55
# VA-lockdown index: 38
#
# Creating SIR for Portugal
# Loaded country's population
# Loaded time series of 106 days
# Lockdown at 2020-03-18 -> at day 56
# VA-lockdown index: 39
#
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[6.59342625e-01, 3.07031917e-01, 2.36789546e-04, 1.73432228e-01],
#        [6.59330518e-01, 3.06956162e-01, 2.36739455e-04, 1.73446465e-01],
#        [6.59327739e-01, 3.07053981e-01, 2.36805799e-04, 1.73420755e-01],
#        [6.59348004e-01, 3.06957946e-01, 2.36745392e-04, 1.73453697e-01],
#        [6.59320073e-01, 3.07106184e-01, 2.36841904e-04, 1.73404039e-01]]), array([2.08374639e-09, 2.08374738e-09, 2.08375488e-09, 2.08375646e-09,
#        2.08376203e-09]))
#            fun: 2.0837463911414673e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 666
#            nit: 399
#         status: 0
#        success: True
#              x: array([6.59342625e-01, 3.07031917e-01, 2.36789546e-04, 1.73432228e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[8.95245772e-01, 3.79646585e-01, 8.31273723e-06, 1.93782584e-01],
#        [8.95205974e-01, 3.80367019e-01, 8.31848349e-06, 1.93607231e-01],
#        [8.94364891e-01, 3.80127671e-01, 8.41403554e-06, 1.93533591e-01],
#        [8.94786046e-01, 3.79669022e-01, 8.38627298e-06, 1.93739149e-01],
#        [8.94730269e-01, 3.80213238e-01, 8.35562978e-06, 1.93547943e-01]]), array([1.34760954e-09, 1.34821988e-09, 1.34884417e-09, 1.34896161e-09,
#        1.34901657e-09]))
#            fun: 1.3476095365857387e-09
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 4000
#            nit: 2434
#         status: 1
#        success: False
#              x: array([8.95245772e-01, 3.79646585e-01, 8.31273723e-06, 1.93782584e-01])
# begin TRYHARD
# # add. Fits until SUCCESS: 1
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[1.14761417e+00, 3.96670507e-01, 1.55359623e-07, 2.15871878e-01],
#        [1.14725269e+00, 3.97076764e-01, 1.55451512e-07, 2.15713149e-01],
#        [1.14747042e+00, 3.97235715e-01, 1.55281205e-07, 2.15729621e-01],
#        [1.14740620e+00, 3.96698736e-01, 1.56232537e-07, 2.15864561e-01],
#        [1.14677318e+00, 3.97055086e-01, 1.57071721e-07, 2.15687267e-01]]), array([6.36685736e-09, 6.36771948e-09, 6.36835492e-09, 6.36844747e-09,
#        6.36866473e-09]))
#            fun: 6.366857356517189e-09
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 4000
#            nit: 2467
#         status: 1
#        success: False
#              x: array([1.14761417e+00, 3.96670507e-01, 1.55359623e-07, 2.15871878e-01])
# begin TRYHARD
# # add. Fits until SUCCESS: 1
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[8.23275399e-01, 2.63706743e-01, 7.09464165e-06, 1.92256086e-01],
#        [8.23281340e-01, 2.63627699e-01, 7.09565619e-06, 1.92275547e-01],
#        [8.23269502e-01, 2.63755397e-01, 7.09338278e-06, 1.92242811e-01],
#        [8.23321265e-01, 2.63624458e-01, 7.09576303e-06, 1.92289150e-01],
#        [8.23264973e-01, 2.63744519e-01, 7.09355179e-06, 1.92243889e-01]]), array([8.82046502e-10, 8.82051617e-10, 8.82052119e-10, 8.82052139e-10,
#        8.82054045e-10]))
#            fun: 8.820465015603424e-10
#        message: 'Optimization terminated successfully.'
#           nfev: 1368
#            nit: 828
#         status: 0
#        success: True
#              x: array([8.23275399e-01, 2.63706743e-01, 7.09464165e-06, 1.92256086e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[1.08297549e+00, 3.24498097e-01, 6.70604696e-07, 2.26548538e-01],
#        [1.08298010e+00, 3.24549051e-01, 6.70135130e-07, 2.26533327e-01],
#        [1.08290481e+00, 3.24484700e-01, 6.70751271e-07, 2.26534465e-01],
#        [1.08294925e+00, 3.24579287e-01, 6.69411239e-07, 2.26508738e-01],
#        [1.08288905e+00, 3.24445467e-01, 6.71242220e-07, 2.26545563e-01]]), array([1.44139368e-09, 1.44139731e-09, 1.44139879e-09, 1.44140605e-09,
#        1.44140702e-09]))
#            fun: 1.4413936791626117e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 1791
#            nit: 1073
#         status: 0
#        success: True
#              x: array([1.08297549e+00, 3.24498097e-01, 6.70604696e-07, 2.26548538e-01])
# Easy SUCCESS
# Start fitting
# End fitting
# Results:
#  final_simplex: (array([[8.81640303e-01, 2.88746851e-01, 1.34666281e-05, 2.14669802e-01],
#        [8.81585706e-01, 2.88659624e-01, 1.34788214e-05, 2.14683876e-01],
#        [8.81645068e-01, 2.88672749e-01, 1.34760498e-05, 2.14697638e-01],
#        [8.81657022e-01, 2.88832611e-01, 1.34550167e-05, 2.14645171e-01],
#        [8.81662490e-01, 2.88670165e-01, 1.34761716e-05, 2.14703139e-01]]), array([3.37660840e-09, 3.37662362e-09, 3.37662923e-09, 3.37662933e-09,
#        3.37664072e-09]))
#            fun: 3.376608403022513e-09
#        message: 'Optimization terminated successfully.'
#           nfev: 445
#            nit: 262
#         status: 0
#        success: True
#              x: array([8.81640303e-01, 2.88746851e-01, 1.34666281e-05, 2.14669802e-01])
# Easy SUCCESS

# %%
print(f'TOTAL RUNTIME:\nseconds={t2-t1}, minutes={np.round((t2-t1)/60.,2)}, hours={np.round((t2-t1)/3600.,2)}')
# Out:
# TOTAL RUNTIME:
# seconds=1210.4481437206268, minutes=20.17, hours=0.34

# %% [markdown]
# # Compact save (still requires previous csv files)

# %%
p_disease=['beta', 'mu', 'I0'] #SIR
#p_disease=['beta_I', 'beta_A', 'mu_I', 'mu_A', 'nu', 'I0']

# %%
mylist=[]
for time in times:
    fname = 'original_params/'+time+'.csv'
    df = pd.read_csv(fname, index_col=0)

    #for country in df.index:
    for country in countries:
        #load AIC and cost
        AIC=df.loc[country]['AIC']
        cost=df.loc[country]['cost']
            
        #load time params
        p_time = list(df.columns[len(p_disease):-2])
        [df[p][country] for p in p_time]
        t_params = [None]*3
        if time =='lock': t_params = [None] + [df[p][country] for p in p_time]
        elif time in ['exp', 'rational']: t_params = [df[p][country] for p in p_time] + [None]*2
        elif time == 'fermi': t_params = [df[p][country] for p in p_time] + [None]
        else: print('unknown time dep')
            
        #load model characteristics(country, time, weights)
        row = [AIC, cost]+[country, time, a_w, r_w] + [df.loc[country][p] for p in p_disease] + t_params
        mylist.append(row)

cols = ['AIC','cost','country','time','a','r','beta', 'mu', 'I0','alpha','t_lock','beta_lock']
SIRs = pd.DataFrame(mylist,columns=cols).sort_values('AIC')
SIRs.index=range(len(SIRs))
SIRs
# Out:
#             AIC          cost         country      time    a    r      beta  \
# 0  -2392.126384  1.015397e-09           Italy     fermi  1.0  0.0  0.527973
# 1  -2338.702259  1.637342e-09           Italy       exp  1.0  0.0  0.817433
# 2  -2338.222500  6.492796e-10         Germany     fermi  1.0  0.0  0.605873
# 3  -2310.735416  2.083746e-09           Italy  rational  1.0  0.0  0.434733
# 4  -2284.657493  7.332349e-10  United Kingdom       exp  1.0  0.0  1.090995
# 5  -2264.886481  8.630762e-10  United Kingdom     fermi  1.0  0.0  0.556409
# 6  -2264.516621  8.820465e-10  United Kingdom  rational  1.0  0.0  0.677782
# 7  -2259.184412  1.347406e-09         Germany  rational  1.0  0.0  0.801258
# 8  -2251.390041  1.445421e-09         Germany       exp  1.0  0.0  0.974763
# 9  -2192.773213  1.146370e-09         Belgium     fermi  1.0  0.0  0.358940
# 10 -2187.615995  3.579906e-09           Spain     fermi  1.0  0.0  0.732715
# 11 -2170.269123  1.441394e-09         Belgium  rational  1.0  0.0  1.172836
# 12 -2136.028454  5.752087e-09           Spain       exp  1.0  0.0  1.708594
# 13 -2124.558397  6.366613e-09           Spain  rational  1.0  0.0  1.316981
# 14 -2123.089159  2.240154e-09         Belgium       exp  1.0  0.0  0.818367
# 15 -2084.078405  2.682307e-09        Portugal       exp  1.0  0.0  1.539336
# 16 -2076.575092  2.825245e-09        Portugal     fermi  1.0  0.0  0.837495
# 17 -2059.677771  3.376608e-09        Portugal  rational  1.0  0.0  0.777290
# 18 -1907.363397  3.149163e-08         Germany      lock  1.0  0.0  0.402257
# 19 -1875.884338  8.697687e-08           Italy      lock  1.0  0.0  0.293131
# 20 -1778.365122  4.708228e-08        Portugal      lock  1.0  0.0  0.412196
# 21 -1776.573807  7.614812e-08  United Kingdom      lock  1.0  0.0  0.331974
# 22 -1757.456262  6.701946e-08         Belgium      lock  1.0  0.0  0.348357
# 23 -1709.463486  2.463553e-07           Spain      lock  1.0  0.0  0.433920
#
#               mu            I0     alpha     t_lock  beta_lock
# 0   1.574845e-04  2.029608e-09  0.060694   4.984973        NaN
# 1   9.883160e-03  1.047817e-09  0.050126        NaN        NaN
# 2   3.007301e-05  6.500659e-13  0.081173  15.660781        NaN
# 3   9.426860e-02  5.606929e-08  0.030079        NaN        NaN
# 4   5.903433e-06  1.075846e-12  0.047444        NaN        NaN
# 5   4.714586e-06  1.573491e-10  0.049607   3.586040        NaN
# 6   6.954125e-02  5.033394e-11  0.036962        NaN        NaN
# 7   1.440788e-01  6.903677e-11  0.037540        NaN        NaN
# 8   8.949474e-02  4.854771e-11  0.039859        NaN        NaN
# 9   1.107264e-03  4.389927e-10  0.070659  20.327098        NaN
# 10  1.299045e-03  1.886536e-15  0.085818  18.047791        NaN
# 11  1.052990e-01  4.497107e-13  0.051324        NaN        NaN
# 12  6.203700e-02  5.841840e-15  0.052049        NaN        NaN
# 13  1.574125e-01  2.415336e-14  0.046593        NaN        NaN
# 14  7.362274e-02  4.707789e-10  0.036881        NaN        NaN
# 15  1.487558e-03  2.106832e-13  0.062532        NaN        NaN
# 16  8.864875e-08  6.361375e-11  0.064080   0.199554        NaN
# 17  8.337474e-02  1.813501e-10  0.046083        NaN        NaN
# 18  1.688112e-01  1.409681e-07       NaN  33.000000   0.158486
# 19  8.135455e-02  5.860644e-07       NaN  34.000000   0.078105
# 20  1.540463e-01  1.497868e-07       NaN  30.000000   0.154091
# 21  1.156079e-01  2.790245e-07       NaN  32.000000   0.131637
# 22  1.370980e-01  1.618659e-07       NaN  41.000000   0.126471
# 23  1.777729e-01  2.188662e-07       NaN  31.000000   0.171560

# %%
fname='original_params/SIR_models.csv'
SIRs.to_csv(fname)
